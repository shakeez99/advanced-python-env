# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "Diana", "Ethan"],
    "Age": [19, 21, 22, 20, 23],
    "Score": [78, 85, 92, 88, 75]
}

df = pd.DataFrame(data)
df

# %%
df.head(3)
df.describe()
average_score = df["Score"].mean()
print("Average Score:", average_score)

# %%
df[df["Age"] > 20]
df[df["Score"] > 80]
